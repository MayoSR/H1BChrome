# %%
import pandas as pd
file_path = 'H1BInfo.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   Line by line  Fiscal Year    Employer (Petitioner) Name  Tax ID  \
# 0            1            2023                        NaN     NaN
# 1            2            2023                        NaN  8070.0
# 2            3            2023                        NaN  8424.0
# 3            4            2023                        NaN  8435.0
# 4            5            2023         1 800 CONTACTS INC  1643.0
#
#                                Industry (NAICS) Code Petitioner City  \
# 0                                                NaN       FAIRFIELD
# 1                                   51 - Information      WILMINGTON
# 2  54 - Professional, Scientific, and Technical S...        BROOKLYN
# 3                         52 - Finance and Insurance        NEW YORK
# 4                               42 - Wholesale Trade          DRAPER
#
#   Petitioner State  Petitioner Zip Code Initial Approval  Initial Denial  \
# 0               IA              52556.0                0               1
# 1               DE              19801.0                1               0
# 2               NY              11220.0                0               0
# 3               NY              10017.0                0               0
# 4               UT              84020.0                0               0
#
#   Continuing Approval  Continuing Denial
# 0                   0                  0
# 1                   0                  0
# 2                   1                  0
# 3                   1                  0
# 4                   2                  0

# %%
filtered_df = df.iloc[:, [1, 2, 8, 9, 10, 11]]

# %%
filtered_df.head()
# Out:
#    Fiscal Year    Employer (Petitioner) Name Initial Approval  Initial Denial  \
# 0            2023                        NaN                0               1
# 1            2023                        NaN                1               0
# 2            2023                        NaN                0               0
# 3            2023                        NaN                0               0
# 4            2023         1 800 CONTACTS INC                0               0
#
#   Continuing Approval  Continuing Denial
# 0                   0                  0
# 1                   0                  0
# 2                   1                  0
# 3                   1                  0
# 4                   2                  0

# %%
filtered_df_2 = filtered_df.dropna()

# %%
row_sums = df.iloc[:,[2,3,4,5]].sum(axis=1)

# Create a boolean mask where True indicates rows with sum >= 1
mask = row_sums >= 1
filtered_df_3 = filtered_df_2[mask]
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_32008\2556214284.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   row_sums = df.iloc[:,[2,3,4,5]].sum(axis=1)
# C:\Users\mayan\AppData\Local\Temp\ipykernel_32008\2556214284.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df_3 = filtered_df_2[mask]

# %%
filtered_df_3
# Out:
#         Fiscal Year                            Employer (Petitioner) Name  \
# 4                 2023                                 1 800 CONTACTS INC
# 5                 2023                              1 800 FLOWERS COM INC
# 6                 2023                          1 ADVANCING EDUCATION LLC
# 7                 2023  1 BETHESDA DRIVE OPERATING COMPANY LLC DBA ELD...
# 8                 2023                            1 HOTEL SOUTH BEACH INC
# ...                ...                                                ...
# 171968            2021                                          ZYTUS INC
# 171969            2021                                          ZYTUS INC
# 171970            2021                                         ZYWAVE INC
# 171971            2021                                          ZYWIE INC
# 171972            2021                                 ZZAN HILLCREST INC
#
#        Initial Approval  Initial Denial Continuing Approval  Continuing Denial
# 4                     0               0                   2                  0
# 5                     0               0                   5                  0
# 6                     0               0                   1                  0
# 7                     0               0                   1                  0
# 8                     0               0                   1                  0
# ...                 ...             ...                 ...                ...
# 171968                0               0                   3                  0
# 171969                1               0                   0                  0
# 171970                1               0                   1                  0
# 171971                0               0                   1                  0
# 171972                0               0                   1                  0
#
# [170191 rows x 6 columns]

# %%
class CompanyRecord(object):
    
    def __init__(self, company_name):
        self.company_name = company_name
        self.yearly_records_map = {}
    
    def insert(self, record):
        self.yearly_records_map[record.year] = record
    
    def add_records_to_year(self,year_record):
        self.yearly_records_map[year_record[0]].add_record(year_record[1::])
        
    def total_H1B_filing_count(self):
        return sum(map(lambda x:x.total_H1B_filing_count_by_year(),self.yearly_records_map.values()))

class YearRecord(object):
    
    def __init__(self, year, sponsor_arr):
        self.year = year
        self.initial_approval,self.initial_denial,self.continuing_approval,self.continuing_denial = [str(i).replace(",","") for i in sponsor_arr]
        
    def total_H1B_filing_count_by_year(self):
        return sum(map(lambda x:int(x),[self.initial_approval,self.initial_denial,self.continuing_approval,self.continuing_denial]))
    
    def add_record(self,sponsor_arr2):
        self.initial_approval += sponsor_arr2[0]
        self.initial_denial += sponsor_arr2[1]
        self.continuing_approval += sponsor_arr2[2]
        self.continuing_denial += sponsor_arr2[3] 
    
    def printer(self):
        print(f'{self.year} {self.initial_approval} {self.initial_denial} {self.continuing_approval} {self.continuing_denial}')

# %%
company_object_map = {}
for row in filtered_df_3.itertuples():
    cr = None
    yr = YearRecord(row[1],[row[3],row[4],row[5],row[6]])
    if row[2] not in company_object_map:
        company_object_map[row[2]] = CompanyRecord(row[2])
        cr = company_object_map[row[2]]
        cr.insert(yr)
    else:
        cr = company_object_map[row[2]]
        cr.add_records_to_year(yr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       9 else:
#      10     cr = company_object_map[row[2]]
# ---> 11     cr.add_records_to_year(yr)
#
# TypeError: CompanyRecord.add_records_to_year() missing 1 required positional argument: 'sponsor_arr2'

# %%
json_dict = {}


for i in company_object_map:
    company_years = {
        
    }
    for item in company_object_map[i].yearly_records_map.items():
        company_years[item[0]] = item[1].__dict__
    json_dict[i] = company_years

years = set(filtered_df_3.iloc[:,0].unique())

for i in json_dict:
    for j in [2023,2022,2021]:
        try:
            del json_dict[i][j]['year']
        except:
            pass

# %%
json_dict

# %%
for i in json_dict:
    for j in years:
        try:
            json_dict[i][j] = [int(json_dict[i][j]['initial_approval']),
                                   int(json_dict[i][j]['initial_denial']),
                                   int(json_dict[i][j]['continuing_approval'])
                                   ,int(json_dict[i][j]['continuing_denial'])]
            
        except:
            pass

# %%
json_dict

# %%
import json

fp = open("companies.json","w")

json.dump(json_dict,fp)

fp.close()

# %%
json_dict['MICROSOFT CORPORATION']
